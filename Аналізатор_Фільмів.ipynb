# %% [markdown]
# <a href="https://colab.research.google.com/github/romanrudniev/MachineLearning/blob/main/%D0%90%D0%BD%D0%B0%D0%BB%D1%96%D0%B7%D0%B0%D1%82%D0%BE%D1%80_%D0%A4%D1%96%D0%BB%D1%8C%D0%BC%D1%96%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Проєкт "Аналізатор фільмів"

# %% [markdown]
# Імпорт бібліотек

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Створення дф та вивід перших п`яти рядків

# %%
url = "movies.csv"

movies_df = pd.read_csv(url)

movies_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4  Just when George Banks has recovered from his ...  ...    1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %% [markdown]
# Інформація про таблицю

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30943 entries, 0 to 30942
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  30943 non-null  object
#  1   belongs_to_collection  3460 non-null   object
#  2   budget                 30943 non-null  object
#  3   genres                 30943 non-null  object
#  4   homepage               5032 non-null   object
#  5   id                     30943 non-null  object
#  6   imdb_id                30931 non-null  object
#  7   original_language      30940 non-null  object
#  8   original_title         30943 non-null  object
#  9   overview               30572 non-null  object
#  10  popularity             30939 non-null  float64
#  11  poster_path            30774 non-null  object
#  12  production_companies   30941 non-null  object
#  13  production_countries   30941 non-null  object
#  14  release_date           30910 non-null  object
#  15  revenue                30939 non-null  float64
#  16  runtime                30856 non-null  float64
#  17  spoken_languages       30939 non-null  object
#  18  status                 30894 non-null  object
#  19  tagline                16183 non-null  object
#  20  title                  30938 non-null  object
#  21  video                  30938 non-null  object
#  22  vote_average           30938 non-null  float64
#  23  vote_count             30938 non-null  float64
# dtypes: float64(5), object(19)
# memory usage: 5.7+ MB

# %% [markdown]
# вивід мінімального максимального і тд

# %%
movies_df.describe()
# Out:
#          popularity       revenue       runtime  vote_average    vote_count
# count  30939.000000  3.093900e+04  30856.000000  30938.000000  30938.000000
# mean       3.495481  1.495586e+07     97.340939      5.776737    143.342621
# std        6.152880  7.368835e+07     34.224786      1.725488    569.649973
# min        0.000000  0.000000e+00      0.000000      0.000000      0.000000
# 25%        0.541000  0.000000e+00     87.000000      5.200000      4.000000
# 50%        1.564398  0.000000e+00     96.000000      6.100000     14.000000
# 75%        5.223358  0.000000e+00    108.000000      6.800000     52.000000
# max      547.488298  2.787965e+09   1256.000000     10.000000  14075.000000

# %% [markdown]
# Попередння обробка та очищення даних

# %%
movies_df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    27483
# budget                       0
# genres                       0
# homepage                 25911
# id                           0
# imdb_id                     12
# original_language            3
# original_title               0
# overview                   371
# popularity                   4
# poster_path                169
# production_companies         2
# production_countries         2
# release_date                33
# revenue                      4
# runtime                     87
# spoken_languages             4
# status                      49
# tagline                  14760
# title                        5
# video                        5
# vote_average                 5
# vote_count                   5
# dtype: int64

# %%
movies_df.dropna(inplace=True)
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 600 entries, 9 to 30805
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  600 non-null    object
#  1   belongs_to_collection  600 non-null    object
#  2   budget                 600 non-null    object
#  3   genres                 600 non-null    object
#  4   homepage               600 non-null    object
#  5   id                     600 non-null    object
#  6   imdb_id                600 non-null    object
#  7   original_language      600 non-null    object
#  8   original_title         600 non-null    object
#  9   overview               600 non-null    object
#  10  popularity             600 non-null    float64
#  11  poster_path            600 non-null    object
#  12  production_companies   600 non-null    object
#  13  production_countries   600 non-null    object
#  14  release_date           600 non-null    object
#  15  revenue                600 non-null    float64
#  16  runtime                600 non-null    float64
#  17  spoken_languages       600 non-null    object
#  18  status                 600 non-null    object
#  19  tagline                600 non-null    object
#  20  title                  600 non-null    object
#  21  video                  600 non-null    object
#  22  vote_average           600 non-null    float64
#  23  vote_count             600 non-null    float64
# dtypes: float64(5), object(19)
# memory usage: 117.2+ KB

# %% [markdown]
# в стовбчику homepage пісті рядки заміняємо на with out link

# %%
movies_df['homepage'].fillna('with out link', inplace=True)
#movies_df['homepage'].fillna(df_movies[''].mean(), inplace=True)
# Out:
# /tmp/ipython-input-2979500923.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   movies_df['homepage'].fillna('with out link', inplace=True)

# %% [markdown]
# вивід перших. 5 рядків

# %%
movies_df.head()
# Out:
#      adult                              belongs_to_collection    budget  \
# 9    False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 68   False  {'id': 43563, 'name': 'Friday Collection', 'po...   3500000
# 69   False  {'id': 10924, 'name': 'From Dusk Till Dawn Col...  19000000
# 153  False  {'id': 439053, 'name': 'Brooklyn Cigar Store C...   2000000
# 178  False  {'id': 286162, 'name': 'Power Rangers Collecti...  15000000
#
#                                                 genres  \
# 9    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 68                      [{'id': 35, 'name': 'Comedy'}]
# 69   [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 153                     [{'id': 35, 'name': 'Comedy'}]
# 178  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                               homepage     id    imdb_id  \
# 9         http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
# 68       http://www.newline.com/properties/friday.html  10634  tt0113118
# 69   http://www.miramax.com/movie/from-dusk-till-dawn/    755  tt0116367
# 153         http://miramax.com/movie/blue-in-the-face/   5894  tt0112541
# 178                       http://www.powerrangers.com/   9070  tt0113820
#
#     original_language                           original_title  \
# 9                  en                                GoldenEye
# 68                 en                                   Friday
# 69                 en                      From Dusk Till Dawn
# 153                en                         Blue in the Face
# 178                en  Mighty Morphin Power Rangers: The Movie
#
#                                               overview  ...  release_date  \
# 9    James Bond must unmask the mysterious head of ...  ...    1995-11-16
# 68   Craig and Smokey are two guys in Los Angeles h...  ...    1995-04-26
# 69   Seth Gecko and his younger brother Richard are...  ...    1996-01-19
# 153  Auggie runs a small tobacco shop in Brooklyn, ...  ...    1995-09-15
# 178  Power up with six incredible teens who out-man...  ...    1995-06-30
#
#          revenue runtime                                   spoken_languages  \
# 9    352194034.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 68    28215918.0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 69    25836616.0   108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 153    1275000.0    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 178   66000000.0    92.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#        status                                            tagline  \
# 9    Released               No limits. No fears. No substitutes.
# 68   Released  A lot can go down between thursday and saturda...
# 69   Released  One night is all that stands between them and ...
# 153  Released                    Welcome to the planet Brooklyn.
# 178  Released                                   The Power Is On!
#
#                                        title  video vote_average vote_count
# 9                                  GoldenEye  False          6.6     1194.0
# 68                                    Friday  False          7.0      513.0
# 69                       From Dusk Till Dawn  False          6.9     1644.0
# 153                         Blue in the Face  False          6.8       28.0
# 178  Mighty Morphin Power Rangers: The Movie  False          5.2      153.0
#
# [5 rows x 24 columns]

# %% [markdown]
# створення стовбчику release_year в який заносими рік виходу зі стовпчику release_date

# %%
movies_df['release_year'] = pd.to_datetime(movies_df['release_date']).dt.year

# %% [markdown]
# вивід перших 5 рядків

# %%
movies_df.head()
# Out:
#     adult                              belongs_to_collection    budget  \
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 18  False  {'id': 3167, 'name': 'Ace Ventura Collection',...  30000000
#
#                                                genres  \
# 2   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 4                      [{'id': 35, 'name': 'Comedy'}]
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 18  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
#
#                                         homepage     id    imdb_id  \
# 2                                  with out link  15602  tt0113228
# 4                                  with out link  11862  tt0113041
# 9   http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
# 12                                 with out link  21032  tt0112453
# 18                                 with out link   9273  tt0112281
#
#    original_language                  original_title  \
# 2                 en                Grumpier Old Men
# 4                 en     Father of the Bride Part II
# 9                 en                       GoldenEye
# 12                en                           Balto
# 18                en  Ace Ventura: When Nature Calls
#
#                                              overview  ...      revenue  \
# 2   A family wedding reignites the ancient feud be...  ...          0.0
# 4   Just when George Banks has recovered from his ...  ...   76578911.0
# 9   James Bond must unmask the mysterious head of ...  ...  352194034.0
# 12  An outcast half-wolf risks his life to prevent...  ...   11348324.0
# 18  Summoned from an ashram in Tibet, Ace finds hi...  ...  212385533.0
#
#    runtime                                   spoken_languages    status  \
# 2    101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4    106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 9    130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 12    78.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 18    90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 2   Still Yelling. Still Fighting. Still Ready for...
# 4   Just When His World Is Back To Normal... He's ...
# 9                No limits. No fears. No substitutes.
# 12                     Part Dog. Part Wolf. All Hero.
# 18            New animals. New adventures. Same hair.
#
#                              title  video vote_average vote_count release_year
# 2                 Grumpier Old Men  False          6.5       92.0         1995
# 4      Father of the Bride Part II  False          5.7      173.0         1995
# 9                        GoldenEye  False          6.6     1194.0         1995
# 12                           Balto  False          7.1      423.0         1995
# 18  Ace Ventura: When Nature Calls  False          6.1     1128.0         1995
#
# [5 rows x 25 columns]

# %% [markdown]
# вивід стовпчіків release_date, release_year

# %%
movies_df[['release_date', 'release_year']]
# Out:
#       release_date  release_year
# 2       1995-12-22          1995
# 4       1995-02-10          1995
# 9       1995-11-16          1995
# 12      1995-12-22          1995
# 18      1995-11-10          1995
# ...            ...           ...
# 45240   1973-04-13          1973
# 45241   1972-09-28          1972
# 45258   2017-07-21          2017
# 45353   1967-03-15          1967
# 45358   1969-05-29          1969
#
# [2572 rows x 2 columns]
